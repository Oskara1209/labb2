# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# make a varible for english that reads in the rigt excel file and sheet, skip the rows that we dont need
df_engelska = pd.read_excel("data/riket2023_åk9_np.xlsx", sheet_name= "Engelska", skiprows= 8)
df_engelska
# Out:
#    Riket Typ av huvudman  Totalt  Flickor  Pojkar  Totalt   Flickor   Pojkar   \
# 0  Riket        Samtliga  106941    51864   55077     97.0      97.1     97.0
# 1  Riket        Kommunal   84310    40675   43635     96.6      96.6     96.6
# 2  Riket         Enskild   22582    11165   11417     98.7      98.8     98.7
# 3  Riket      Skolverket      49       24      25    100.0     100.0    100.0
#
#    Totalt    Flickor    Pojkar
# 0      15.7       15.8      15.7
# 1      15.4       15.5      15.4
# 2      16.9       17.0      16.8
# 3      18.5       18.9      18.2

# %%
# make a varible for math that reads in the rigt excel file and sheet, skip the rows that we dont need
df_matematik = pd.read_excel("data/riket2023_åk9_np.xlsx", sheet_name= "Matematik", skiprows=8)
df_matematik
# Out:
#    Riket Typ av huvudman  Totalt  Flickor  Pojkar Totalt  Flickor  Pojkar   \
# 0  Riket        Samtliga  106766    51548   55218    89.1     88.7    89.5
# 1  Riket        Kommunal   84163    40386   43777    88.1     87.7    88.5
# 2  Riket         Enskild   22553    11137   11416    92.9     92.2    93.5
# 3  Riket      Skolverket      50       25      25    ~100     ~100    ~100
#
#    Totalt    Flickor    Pojkar
# 0      11.9       11.8      12.0
# 1      11.6       11.5      11.7
# 2      13.0       12.8      13.1
# 3      14.1       13.5      14.7

# %%
# make a varible for swedish that reads in the rigt excel file and sheet, skip the rows that we dont need
df_svenska = pd.read_excel("data/riket2023_åk9_np.xlsx", sheet_name= "Svenska", skiprows=8)
df_svenska
# Out:
#    Riket Typ av huvudman  Totalt  Flickor  Pojkar  Totalt   Flickor   Pojkar   \
# 0  Riket        Samtliga   93225    45800   47425     96.1      97.9     94.4
# 1  Riket        Kommunal   72771    35484   37287     95.7      97.6     93.8
# 2  Riket         Enskild   20414    10297   10117     97.6      98.7     96.6
# 3  Riket      Skolverket      40       19      21    100.0     100.0    100.0
#
#    Totalt    Flickor    Pojkar
# 0      13.6       14.5      12.7
# 1      13.3       14.3      12.4
# 2      14.4       15.2      13.5
# 3      15.0       15.9      14.2

# %%
# make a varible for swedish as secound language that reads in the rigt excel file and sheet, skip the rows that we dont need 
df_svenska_som_andraspråk = pd.read_excel("data/riket2023_åk9_np.xlsx", sheet_name= "Svenska som andraspråk", skiprows=8)
df_svenska_som_andraspråk
# Out:
#    Riket Typ av huvudman Totalt Flickor Pojkar Totalt  Flickor  Pojkar   \
# 0  Riket        Samtliga  14092    6447   7645    77.7     81.6    74.3
# 1  Riket        Kommunal  11963    5495   6468    75.9       80    72.4
# 2  Riket         Enskild   2122     949   1173    87.7     90.9    85.2
# 3  Riket      Skolverket     ..      ..     ..      ..       ..      ..
#
#   Totalt   Flickor   Pojkar
# 0      9.4      10.2      8.7
# 1        9       9.9      8.3
# 2     11.1        12     10.4
# 3       ..        ..       ..

# %%
#Show columns for english sheet 
df_engelska.columns
# Out:
# Index(['Riket', 'Typ av huvudman', 'Totalt', 'Flickor', 'Pojkar', 'Totalt ',
#        'Flickor ', 'Pojkar ', 'Totalt  ', 'Flickor  ', 'Pojkar  '],
#       dtype='object')

# %%
#rename the columns 
df_engelska = df_engelska.rename({"Riket": "Plats", "Typ av huvudman": "Huvudman", "Totalt": "Totalt (A-F)", "Flickor": "Flickor (A-F)", "Pojkar": "Pojkar (A-F)", "Totalt ": "Totalt (A-E)", "Flickor ": "Flickor (A-E)", "Pojkar ": "Pojkar (A-E)", "Totalt  ": "Totalt (Poäng)", "Flickor  ": "Flickor (Poäng)", "Pojkar  ": "Pojkar (Poäng)"},axis= "columns")
df_engelska
# Out:
#    Plats    Huvudman  Totalt (A-F)  Flickor (A-F)  Pojkar (A-F)  Totalt (A-E)  \
# 0  Riket    Samtliga        106941          51864         55077          97.0
# 1  Riket    Kommunal         84310          40675         43635          96.6
# 2  Riket     Enskild         22582          11165         11417          98.7
# 3  Riket  Skolverket            49             24            25         100.0
#
#    Flickor (A-E)  Pojkar (A-E)  Totalt (Poäng)  Flickor (Poäng)  \
# 0           97.1          97.0            15.7             15.8
# 1           96.6          96.6            15.4             15.5
# 2           98.8          98.7            16.9             17.0
# 3          100.0         100.0            18.5             18.9
#
#    Pojkar (Poäng)
# 0            15.7
# 1            15.4
# 2            16.8
# 3            18.2

# %%
#rename the columns 
df_matematik.columns
# Out:
# Index(['Riket', 'Typ av huvudman', 'Totalt', 'Flickor', 'Pojkar', 'Totalt ',
#        'Flickor ', 'Pojkar ', 'Totalt  ', 'Flickor  ', 'Pojkar  '],
#       dtype='object')

# %%
#rename the columns 
df_matematik = df_matematik.rename({"Riket": "Plats", "Typ av huvudman": "Huvudman", "Totalt": "Totalt (A-F)", "Flickor": "Flickor (A-F)", "Pojkar": "Pojkar (A-F)", "Totalt ": "Totalt (A-E)", "Flickor ": "Flickor (A-E)", "Pojkar ": "Pojkar (A-E)", "Totalt  ": "Totalt (Poäng)", "Flickor  ": "Flickor (Poäng)", "Pojkar  ": "Pojkar (Poäng)"},axis= "columns")
df_matematik
# Out:
#    Plats    Huvudman  Totalt (A-F)  Flickor (A-F)  Pojkar (A-F) Totalt (A-E)  \
# 0  Riket    Samtliga        106766          51548         55218         89.1
# 1  Riket    Kommunal         84163          40386         43777         88.1
# 2  Riket     Enskild         22553          11137         11416         92.9
# 3  Riket  Skolverket            50             25            25         ~100
#
#   Flickor (A-E) Pojkar (A-E)  Totalt (Poäng)  Flickor (Poäng)  Pojkar (Poäng)
# 0          88.7         89.5            11.9             11.8            12.0
# 1          87.7         88.5            11.6             11.5            11.7
# 2          92.2         93.5            13.0             12.8            13.1
# 3          ~100         ~100            14.1             13.5            14.7

# %%
#rename the columns 
df_svenska = df_svenska.rename({"Riket": "Plats", "Typ av huvudman": "Huvudman", "Totalt": "Totalt (A-F)", "Flickor": "Flickor (A-F)", "Pojkar": "Pojkar (A-F)", "Totalt ": "Totalt (A-E)", "Flickor ": "Flickor (A-E)", "Pojkar ": "Pojkar (A-E)", "Totalt  ": "Totalt (Poäng)", "Flickor  ": "Flickor (Poäng)", "Pojkar  ": "Pojkar (Poäng)"},axis= "columns")
df_svenska
# Out:
#    Plats    Huvudman  Totalt (A-F)  Flickor (A-F)  Pojkar (A-F)  Totalt (A-E)  \
# 0  Riket    Samtliga         93225          45800         47425          96.1
# 1  Riket    Kommunal         72771          35484         37287          95.7
# 2  Riket     Enskild         20414          10297         10117          97.6
# 3  Riket  Skolverket            40             19            21         100.0
#
#    Flickor (A-E)  Pojkar (A-E)  Totalt (Poäng)  Flickor (Poäng)  \
# 0           97.9          94.4            13.6             14.5
# 1           97.6          93.8            13.3             14.3
# 2           98.7          96.6            14.4             15.2
# 3          100.0         100.0            15.0             15.9
#
#    Pojkar (Poäng)
# 0            12.7
# 1            12.4
# 2            13.5
# 3            14.2

# %%
#rename the columns 
df_svenska_som_andraspråk = df_svenska_som_andraspråk.rename({"Riket": "Plats", "Typ av huvudman": "Huvudman", "Totalt": "Totalt (A-F)", "Flickor": "Flickor (A-F)", "Pojkar": "Pojkar (A-F)", "Totalt ": "Totalt (A-E)", "Flickor ": "Flickor (A-E)", "Pojkar ": "Pojkar (A-E)", "Totalt  ": "Totalt (Poäng)", "Flickor  ": "Flickor (Poäng)", "Pojkar  ": "Pojkar (Poäng)"},axis= "columns")
df_svenska_som_andraspråk
# Out:
#    Plats    Huvudman Totalt (A-F) Flickor (A-F) Pojkar (A-F) Totalt (A-E)  \
# 0  Riket    Samtliga        14092          6447         7645         77.7
# 1  Riket    Kommunal        11963          5495         6468         75.9
# 2  Riket     Enskild         2122           949         1173         87.7
# 3  Riket  Skolverket           ..            ..           ..           ..
#
#   Flickor (A-E) Pojkar (A-E) Totalt (Poäng) Flickor (Poäng) Pojkar (Poäng)
# 0          81.6         74.3            9.4            10.2            8.7
# 1            80         72.4              9             9.9            8.3
# 2          90.9         85.2           11.1              12           10.4
# 3            ..           ..             ..              ..             ..

# %%
#convert total points to float 
df_engelska["Totalt (Poäng)"] = df_engelska["Totalt (Poäng)"].astype(float)

# %%
#convert total points to float 
df_matematik["Totalt (Poäng)"] = df_matematik["Totalt (Poäng)"].astype(float)

# %%
#convert total points to float 
df_svenska["Totalt (Poäng)"] = df_svenska["Totalt (Poäng)"].astype(float)

# %%
import numpy as np

# change ".." to NaN and convert to float
df_svenska_som_andraspråk["Totalt (Poäng)"] = df_svenska_som_andraspråk["Totalt (Poäng)"].replace("..", np.nan)
df_svenska_som_andraspråk["Totalt (Poäng)"] = pd.to_numeric(df_svenska_som_andraspråk["Totalt (Poäng)"], errors='coerce')

# control the value 
print(df_svenska_som_andraspråk[["Huvudman", "Totalt (Poäng)"]])
# Out:
#      Huvudman  Totalt (Poäng)
# 0    Samtliga             9.4
# 1    Kommunal             9.0
# 2     Enskild            11.1
# 3  Skolverket             NaN
# C:\Users\oskar\AppData\Local\Temp\ipykernel_740\113844361.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_svenska_som_andraspråk["Totalt (Poäng)"] = df_svenska_som_andraspråk["Totalt (Poäng)"].replace("..", np.nan)

# %%
import os
import matplotlib.pyplot as plt

# create a submap called 'visualiseringar' 
# (Detta tog jag hjälp av chat gpt för att förstå, os är en inbyggd python modell som hjälper att skapa och lagra mappar och filer med mera)
output_dir = "visualiseringar"
os.makedirs(output_dir, exist_ok=True)

# lista med dataframes och titlar
# make a list of dataframes and titles 
subjects = ["Engelska", "Matematik", "Svenska", "Svenska som andraspråk"]
dataframes = [df_engelska, df_matematik, df_svenska, df_svenska_som_andraspråk]

# create the figure
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle("Totala Poäng per Huvudman för olika Ämnen", fontsize=16)

# loopa genom ämnen och plotta
# loop trough the subjects and plot 
for ax, df, subjects in zip(axes.flatten(), dataframes, subjects):
    # Filtrera ut relevanta kolumner
    # filter out the columns 
    df_filtered = df[["Huvudman", "Totalt (Poäng)"]]
    ax.bar(df_filtered["Huvudman"], df_filtered["Totalt (Poäng)"])
    ax.set_title(subjects, fontsize=14)
    ax.set_xlabel("Huvudman", fontsize=12)
    ax.set_ylabel("Totalt (Poäng)", fontsize=12)
    ax.set_xticklabels(df_filtered["Huvudman"], rotation=45, ha="right")

# got this code from chat gpt to make it look better 
plt.tight_layout(rect=[0, 0, 1, 0.96])

# save figure 
output_path = os.path.join(output_dir, "totala_poäng_per_huvudman.png")
plt.savefig(output_path, dpi=300)

# show
plt.show()
# Out:
# C:\Users\oskar\AppData\Local\Temp\ipykernel_740\3710174194.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_filtered["Huvudman"], rotation=45, ha="right")
# C:\Users\oskar\AppData\Local\Temp\ipykernel_740\3710174194.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_filtered["Huvudman"], rotation=45, ha="right")
# C:\Users\oskar\AppData\Local\Temp\ipykernel_740\3710174194.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_filtered["Huvudman"], rotation=45, ha="right")
# ...
